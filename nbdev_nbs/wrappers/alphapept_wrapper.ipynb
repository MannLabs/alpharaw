# %%
#---#| default_exp wrappers.alphapept_wrapper

# %% [markdown]
# # AlphaPept MS Data Wrapper

# %% [markdown]
# @TODO Leave this to Max S.:)

# %%
from alpharaw.wrappers.alphapept_wrapper import *

# %%
#| hide
import os
reader = ms_reader_provider.get_reader('alphapept')
hdf = '/Users/zengwenfeng/Workspace/Data/Thermo_iRT/iRT.ms_data.hdf'
if os.path.isfile(hdf):
    reader.import_raw('/Users/zengwenfeng/Workspace/Data/Thermo_iRT/iRT.ms_data.hdf')
    display(reader.spectrum_df)
# Out:
#       spec_idx  peak_start_idx  peak_stop_idx        rt  ms_level  \
# 0            0               0             0  0.000000         2
# 2664      2664               0             0  0.000000         2
# 2662      2662               0             0  0.000000         2
# 2660      2660               0             0  0.000000         2
# 2659      2659               0             0  0.000000         2
# ...        ...             ...           ...       ...       ...
# 3924      3924           95305         95339  5.976648         2
# 3925      3925           95339         95362  5.977300         2
# 3927      3927           95362         95393  5.981044         2
# 3933      3933           95393         95409  5.997334         2
# 3935      3935           95409         95422  6.001193         2
#
#       precursor_mz  isolation_lower_mz  isolation_upper_mz
# 0           0.0000             -2.0000              2.0000
# 2664        0.0000             -2.0000              2.0000
# ...
