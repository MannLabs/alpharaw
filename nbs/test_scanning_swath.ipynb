# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from alpharaw.sciex import SciexWiffData

raw_data = SciexWiffData()
raw_data.import_raw(
    "/Users/zengwenfeng/Workspace/Data/DIA_data/scanningSWATH/20201215_sswath_1min_5ug_1.wiff"
)
raw_data.spectrum_df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from alpharaw.sciex import SciexWiffData
#       3 raw_data = SciexWiffData()
#       4 raw_data.import_raw(
#       5     "/Users/zengwenfeng/Workspace/Data/DIA_data/scanningSWATH/20201215_sswath_1min_5ug_1.wiff"
#       6 )
#
# File ~/workspace/alpharaw/alpharaw/sciex.py:5
#       3 import os
#       4 import warnings
# ----> 5 import alpharaw.raw_access.pysciexwifffilereader as pysciexwifffilereader
#       6 from .ms_data_base import MSData_Base
#       7 from .ms_data_base import ms_reader_provider
#
# File ~/workspace/alpharaw/alpharaw/raw_access/pysciexwifffilereader.py:9
#       6 from alpharaw.utils.centroiding import centroid_peaks
#       8 # require pythonnet, pip install pythonnet on Windows
# ----> 9 import clr
#      10 clr.AddReference('System')
#      11 import System
#
# ModuleNotFoundError: No module named 'clr'

# %%
raw_data.peak_df
# Out:
#       spec_idx  peak_start_idx  peak_stop_idx        rt  ms_level  \
# 783        783           46259         46449  0.015499         1
# 784        784           46449         46449  0.015740         2
# 785        785           46449         46449  0.015745         2
# 786        786           46449         46449  0.015749         2
# 787        787           46449         46449  0.015754         2
# ...        ...             ...           ...       ...       ...
# 1039      1039           61814         61840  0.016899         2
# 1040      1040           61840         61863  0.016904         2
# 1041      1041           61863         61887  0.016908         2
# 1042      1042           61887         61908  0.016913         2
# 1043      1043           61908         61922  0.016917         2
#
#       precursor_mz  charge  isolation_lower_mz  isolation_upper_mz  \
# 783      -1.000000      -1           -1.000000           -1.000000
# 784     378.989823       0          377.989823          379.989823
# 785     380.995054       0          379.989823          382.000285
# 786     383.000285       0          382.000285          384.000285
# 787     385.005515       0          384.000285          386.010746
# ...            ...     ...                 ...                 ...
# 1039    890.788651       0          889.779935          891.797367
# 1040    892.798301       0          891.797367          893.799235
# 1041    894.807950       0          893.799235          895.816666
# 1042    896.817600       0          895.816666          897.818534
# 1043    898.827250       0          897.818534          899.835966
#
#       experiment_id  cycle_id    rt_sec
# 783               0         3  0.929926
# 784               1         3  0.944400
# 785               2         3  0.944673
# 786               3         3  0.944946
# 787               4         3  0.945219
# ...             ...       ...       ...
# 1039            256         3  1.013940
# 1040            257         3  1.014212
# 1041            258         3  1.014485
# 1042            259         3  1.014758
# 1043            260         3  1.015030
#
# [261 rows x 12 columns]
